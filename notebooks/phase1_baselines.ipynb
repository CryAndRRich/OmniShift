# %% [markdown]
# # Phase 1 — Baselines: ResNet-20, DeepShift, APoT, DenseShift

# %% [markdown]
# ## Setup — clone repo and install dependencies

# %%
import os, subprocess
if not os.path.exists('/kaggle/working/OmniShift'):
    subprocess.run(['git','clone','https://github.com/CryAndRRich/OmniShift.git','/kaggle/working/OmniShift'], check=True)
os.chdir('/kaggle/working/OmniShift')
# !pip install -q pyyaml

# %% [markdown]
# ## Verify GPU

# %%
import torch
device = 'cuda' if torch.cuda.is_available() else 'cpu'
gpu_name = torch.cuda.get_device_name(0) if device == 'cuda' else 'CPU only'
print(f'Device : {gpu_name}')
print(f'PyTorch: {torch.__version__}')

# %% [markdown]
# ## Training runs

# %% [markdown]
# ### CIFAR-10 · resnet20

# %%
# !python scripts/run_experiment.py --config configs/phase1_baselines.yaml --name resnet20 --dataset cifar10

# %% [markdown]
# ### CIFAR-10 · deepshift

# %%
# !python scripts/run_experiment.py --config configs/phase1_baselines.yaml --name deepshift --dataset cifar10

# %% [markdown]
# ### CIFAR-10 · apot

# %%
# !python scripts/run_experiment.py --config configs/phase1_baselines.yaml --name apot --dataset cifar10

# %% [markdown]
# ### CIFAR-10 · denseshift

# %%
# !python scripts/run_experiment.py --config configs/phase1_baselines.yaml --name denseshift --dataset cifar10

# %% [markdown]
# ### SVHN · resnet20

# %%
# !python scripts/run_experiment.py --config configs/phase1_baselines.yaml --name resnet20 --dataset svhn

# %% [markdown]
# ### SVHN · deepshift

# %%
# !python scripts/run_experiment.py --config configs/phase1_baselines.yaml --name deepshift --dataset svhn

# %% [markdown]
# ### SVHN · apot

# %%
# !python scripts/run_experiment.py --config configs/phase1_baselines.yaml --name apot --dataset svhn

# %% [markdown]
# ### SVHN · denseshift

# %%
# !python scripts/run_experiment.py --config configs/phase1_baselines.yaml --name denseshift --dataset svhn

# %% [markdown]
# ## Results summary

# %%
# !python scripts/summarize_results.py
