# %% [markdown]
# # Phase 2 — PoT-BN: DeepShift with Power-of-Two Batch Normalization

# %% [markdown]
# ## Setup — clone repo and install dependencies

# %%
import os, subprocess
if not os.path.exists('/kaggle/working/OmniShift'):
    subprocess.run(['git','clone','https://github.com/CryAndRRich/OmniShift.git','/kaggle/working/OmniShift'], check=True)
os.chdir('/kaggle/working/OmniShift')
# !pip install -q pyyaml

# %% [markdown]
# ## Verify GPU

# %%
import torch
device = 'cuda' if torch.cuda.is_available() else 'cpu'
gpu_name = torch.cuda.get_device_name(0) if device == 'cuda' else 'CPU only'
print(f'Device : {gpu_name}')
print(f'PyTorch: {torch.__version__}')

# %% [markdown]
# ## Training runs

# %% [markdown]
# ### CIFAR-10 · deepshift_std

# %%
# !python scripts/run_experiment.py --config configs/phase2_potbn.yaml --name deepshift_std --dataset cifar10

# %% [markdown]
# ### CIFAR-10 · deepshift_potbn

# %%
# !python scripts/run_experiment.py --config configs/phase2_potbn.yaml --name deepshift_potbn --dataset cifar10

# %% [markdown]
# ### CIFAR-10 · deepshift_potbn_warmup10

# %%
# !python scripts/run_experiment.py --config configs/phase2_potbn.yaml --name deepshift_potbn_warmup10 --dataset cifar10

# %% [markdown]
# ### CIFAR-10 · deepshift_potbn_warmup30

# %%
# !python scripts/run_experiment.py --config configs/phase2_potbn.yaml --name deepshift_potbn_warmup30 --dataset cifar10

# %% [markdown]
# ### SVHN · deepshift_std

# %%
# !python scripts/run_experiment.py --config configs/phase2_potbn.yaml --name deepshift_std --dataset svhn

# %% [markdown]
# ### SVHN · deepshift_potbn

# %%
# !python scripts/run_experiment.py --config configs/phase2_potbn.yaml --name deepshift_potbn --dataset svhn

# %% [markdown]
# ### SVHN · deepshift_potbn_warmup10

# %%
# !python scripts/run_experiment.py --config configs/phase2_potbn.yaml --name deepshift_potbn_warmup10 --dataset svhn

# %% [markdown]
# ### SVHN · deepshift_potbn_warmup30

# %%
# !python scripts/run_experiment.py --config configs/phase2_potbn.yaml --name deepshift_potbn_warmup30 --dataset svhn

# %% [markdown]
# ## Results summary

# %%
# !python scripts/summarize_results.py
